# %% [markdown]
# # Data

# %% [markdown]
# ### Reading Dataset & Dataset description

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/external/ton-iot-windows-10.csv")

# %%
df
# Out:
#                ts  Processor_DPC_Rate Processor_pct_ Idle_Time  \
# 0      1554206309                   4              29.90817156
# 1      1554206319                   9              31.75168186
# 2      1554206329                   5              29.49516707
# 3      1554206339                  12              18.22437505
# 4      1554206349                  12              14.86118688
# ...           ...                 ...                      ...
# 35970  1556099926                   0              65.61119892
# 35971  1556099936                   0              96.82941756
# 35972  1556099946                   0              95.29471453
# 35973  1556099956                   0              94.92761932
# 35974  1556099966                   2              93.51933254
#
#       Processor_pct_ C3_Time Processor_pct_ Interrupt_Time  \
# 0                          0                   0.078240397
# 1                          0                   0.312520973
# ...

# %%
df.shape
# Out:
# (35975, 127)

# %%
df.dtypes
# Out:
# ts                                               int64
# Processor_DPC_Rate                               int64
# Processor_pct_ Idle_Time                        object
# Processor_pct_ C3_Time                          object
# Processor_pct_ Interrupt_Time                   object
#                                                  ...
# LogicalDisk(_Total) Avg  Disk Bytes Transfer    object
# LogicalDisk(_Total) pct_ Disk Write Time        object
# LogicalDisk(_Total) Avg  Disk sec Transfer      object
# label                                            int64
# type                                            object
# Length: 127, dtype: object

# %% [markdown]
# ### Merging "label" and "type" columns

# %%
df.drop(columns="label", inplace=True)

# %%
set(df["type"])
# Out:
# {'ddos', 'dos', 'injection', 'mitm', 'normal', 'password', 'scanning', 'xss'}

# %%
labels = {
    "normal": 0,
    "ddos": 1,
    "dos": 2,
    "injection": 3,
    "mitm": 4,
    "password": 5,
    "scanning": 6,
    "xss": 7,
}
df["type"].replace(to_replace=labels, inplace=True)

# %%
set(df["type"])
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %%
df
# Out:
#                ts  Processor_DPC_Rate Processor_pct_ Idle_Time  \
# 0      1554206309                   4              29.90817156
# 1      1554206319                   9              31.75168186
# 2      1554206329                   5              29.49516707
# 3      1554206339                  12              18.22437505
# 4      1554206349                  12              14.86118688
# ...           ...                 ...                      ...
# 35970  1556099926                   0              65.61119892
# 35971  1556099936                   0              96.82941756
# 35972  1556099946                   0              95.29471453
# 35973  1556099956                   0              94.92761932
# 35974  1556099966                   2              93.51933254
#
#       Processor_pct_ C3_Time Processor_pct_ Interrupt_Time  \
# 0                          0                   0.078240397
# 1                          0                   0.312520973
# ...

# %%
df.shape
# Out:
# (35975, 126)

# %%
df.dtypes
# Out:
# ts                                               int64
# Processor_DPC_Rate                               int64
# Processor_pct_ Idle_Time                        object
# Processor_pct_ C3_Time                          object
# Processor_pct_ Interrupt_Time                   object
#                                                  ...
# LogicalDisk(_Total) Disk Transfers sec          object
# LogicalDisk(_Total) Avg  Disk Bytes Transfer    object
# LogicalDisk(_Total) pct_ Disk Write Time        object
# LogicalDisk(_Total) Avg  Disk sec Transfer      object
# type                                             int64
# Length: 126, dtype: object

# %% [markdown]
# ### Train-Test-Validation Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    df.iloc[:, 0:125], df.iloc[:, 125], test_size=0.2, random_state=1
)

# %%
train = pd.DataFrame(X_train.join(Y_train))
train.to_csv("../data/interim/train-split.csv", index=False)

# %%
test = pd.DataFrame(X_test.join(Y_test))
test.to_csv("../data/interim/test-split.csv", index=False)

# %% [markdown]
# # Validation

# %%
X_train = train.iloc[:,:125]
Y_train = train.iloc[:,125]

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold()

# %%
for train_idx, test_idx in skf.split(X_train, Y_train):
    X_train_fold = pd.DataFrame(X_train.iloc[train_idx])
    Y_train_fold = pd.DataFrame(Y_train.iloc[train_idx])
    X_test_fold = pd.DataFrame(X_train.iloc[test_idx])
    Y_test_fold = pd.DataFrame(Y_train.iloc[test_idx])
    print(X_train_fold.shape)
    print(X_test_fold.shape)
# Out:
# (23024, 125)
# (5756, 125)
# (23024, 125)
# (5756, 125)
# (23024, 125)
# (5756, 125)
# (23024, 125)
# (5756, 125)
# (23024, 125)
# (5756, 125)
