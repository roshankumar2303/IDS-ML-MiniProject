# %% [markdown]
# # Data cleaning and Feature Selection

# %% [markdown]
# ### Constants

# %%
DF_COL_COUNT = len(df.columns)

# %% [markdown]
# ### Reading Dataset & Dataset description

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/interim/ton-iot-windows-10.csv')

# %%
df.head()
# Out:
#            ts  Processor_DPC_Rate Processor_pct_ Idle_Time  \
# 0  1554206309                   4              29.90817156
# 1  1554206319                   9              31.75168186
# 2  1554206329                   5              29.49516707
# 3  1554206339                  12              18.22437505
# 4  1554206349                  12              14.86118688
#
#   Processor_pct_ C3_Time Processor_pct_ Interrupt_Time Processor_pct_ C2_Time  \
# 0                      0                   0.078240397                      0
# 1                      0                   0.312520973                      0
# 2                      0                    1.16822183                      0
# 3                      0                   1.097191902                      0
# 4                      0                   1.562431019                      0
#
#   Processor_pct_ User_Time Processor_pct_ C1_Time  \
# 0              61.02750947            29.90817156
# 1              59.14459419            31.75168186
# 2              46.02794011            29.49516707
# 3              47.80621859            18.22437505
# 4               41.8731513            14.86118688
#
#   Processor_pct_ Processor_Time Processor_C1_ransitions_sec  ...  \
# 0                    66.2001486                 480.0949912  ...
# 1                   66.24773489                 427.0412837  ...
# 2                   66.90038148                 1159.426821  ...
# 3                   79.54520811                  736.622011  ...
# 4                   82.73513724                 896.1085985  ...
#
#   LogicalDisk(_Total) Avg  Disk Write Queue Length  \
# 0                                      0.134876119
# 1                                      0.157564294
# 2                                      0.401773775
# 3                                      0.259062331
# 4                                      0.103836186
#
#   LogicalDisk(_Total) Avg  Disk Queue Length  \
# 0                                0.163098103
# 1                                0.189279353
# 2                                0.782471877
# 3                                0.768934004
# 4                                1.081729712
#
#   LogicalDisk(_Total) pct_ Disk Read Time  \
# 0                             2.822198461
# 1                              3.17150584
# 2                             38.06981014
# 3                             50.98716725
# 4                              97.7893526
#
#   LogicalDisk(_Total) Disk Write Bytes sec  \
# 0                              1924988.236
# 1                              1497232.743
# 2                              1854228.536
# 3                              15912390.29
# 4                               23609299.7
#
#   LogicalDisk(_Total) Disk Transfers sec  \
# 0                            402.5827836
# 1                            355.1343322
# 2                            760.4317685
# 3                            699.4999538
# 4                            1184.550425
#
#   LogicalDisk(_Total) Avg  Disk Bytes Transfer  \
# 0                                  9100.481592
# 1                                  11153.55449
# 2                                  26994.26595
# 3                                   53141.6638
# 4                                  40988.68444
#
#    LogicalDisk(_Total) pct_ Disk Write Time  \
# 0                               13.48761188
# 1                               15.75642941
# 2                               40.17737752
# 3                               25.90623311
# 4                               10.38361856
#
#   LogicalDisk(_Total) Avg  Disk sec Transfer  label    type
# 0                                0.000405118      0  normal
# 1                                0.000532995      0  normal
# 2                                0.001028323      0  normal
# 3                                0.001099429      0  normal
# 4                                0.000912738      0  normal
#
# [5 rows x 127 columns]

# %%
df.dtypes
# Out:
# ts                                               int64
# Processor_DPC_Rate                               int64
# Processor_pct_ Idle_Time                        object
# Processor_pct_ C3_Time                          object
# Processor_pct_ Interrupt_Time                   object
#                                                  ...
# LogicalDisk(_Total) Avg  Disk Bytes Transfer    object
# LogicalDisk(_Total) pct_ Disk Write Time        object
# LogicalDisk(_Total) Avg  Disk sec Transfer      object
# label                                            int64
# type                                            object
# Length: 127, dtype: object

# %% [markdown]
# ### Data Cleaning

# %%
total_NaN_count = 0
for column in df.iloc[:, : DF_COL_COUNT - 2]:
    df[column] = pd.to_numeric(df[column], errors="coerce")
    total_NaN_count += df[column].isna().sum()

    column_mean = df[column].mean()
    df[column].fillna(value=column_mean, inplace=True)
print("Total cells replaced: {}".format(total_NaN_count))
# Out:
# Total cells replaced: 3360

# %%
df.dtypes
# Out:
# ts                                                int64
# Processor_DPC_Rate                                int64
# Processor_pct_ Idle_Time                        float64
# Processor_pct_ C3_Time                          float64
# Processor_pct_ Interrupt_Time                   float64
#                                                  ...
# LogicalDisk(_Total) Avg  Disk Bytes Transfer    float64
# LogicalDisk(_Total) pct_ Disk Write Time        float64
# LogicalDisk(_Total) Avg  Disk sec Transfer      float64
# label                                             int64
# type                                             object
# Length: 127, dtype: object

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X = df.iloc[:, 0:125]
Y = df.iloc[:, -2]

# %%
fit = SelectKBest(score_func=chi2, k=10).fit(X, Y)

df_scores = pd.DataFrame(fit.scores_)
df_columns = pd.DataFrame(X.columns)

featureScores = pd.concat([df_columns, df_scores], axis=1)
featureScores.columns = ["Features", "Score"]
featureScores.nlargest(30, "Score")
# Out:
#                                        Features         Score
# 29                        Process_Virtual_Bytes  1.854902e+17
# 23                   Process_Virtual_Bytes Peak  1.854822e+17
# 88          Memory System Driver Resident Bytes  1.424477e+16
# 93        Memory Free System Page Table Entries  2.954608e+12
# 67           Memory Free & Zero Page List Bytes  1.606858e+12
# 33                          Process_Working Set  1.290024e+12
# 24                 Process_Page_File Bytes Peak  1.149956e+12
# 71                          Memory Commit Limit  9.289134e+11
# 19                     Process_Working_Set_Peak  3.929582e+11
# 84           Memory Standby Cache Reserve Bytes  3.525591e+11
# 97                       Memory Committed Bytes  2.371663e+11
# 70                       Memory Available Bytes  1.895827e+11
# 21                      Process_Page_File Bytes  1.859601e+11
# 26                        Process_Private_Bytes  1.859601e+11
# 100            Memory Pool Paged Resident Bytes  1.266462e+11
# 18                 Process_Working_Set_ Private  1.005246e+11
# 113          LogicalDisk(_Total) Disk Bytes sec  6.150937e+10
# 68                      Memory Cache Bytes Peak  5.995520e+10
# 106     LogicalDisk(_Total) Disk Read Bytes sec  4.627214e+10
# 87              Memory Standby Cache Core Bytes  4.424701e+10
# 82           Memory System Cache Resident Bytes  3.507364e+10
# 66                      Memory Pool Paged Bytes  2.784303e+10
# 89   Memory Standby Cache Normal Priority Bytes  2.710360e+10
# 78                           Memory Cache Bytes  1.731452e+10
# 120    LogicalDisk(_Total) Disk Write Bytes sec  1.530911e+10
# 79                   Memory Pool Nonpaged Bytes  1.071017e+10
# 95              Memory Modified Page List Bytes  1.059788e+10
# 16                     Process_Pool_Paged Bytes  8.157800e+09
# 86               Memory System Code Total Bytes  3.840187e+09
# 69            Memory System Code Resident Bytes  2.277744e+09
